# %% [markdown]
# <a href="https://colab.research.google.com/github/raki-rankawat/thesis-v2/blob/master/Teacher_VGG_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 · Teacher Candidate — VGG-Style (from scratch)
#
# Custom 4-block VGG-style CNN trained entirely from random initialization on the VWW dataset.
# Included as a baseline teacher candidate for comparison against the pretrained VGG16-BN.
#
# **Hypothesis:** The pretrained variant will outperform this model due to richer feature
# representations learned on ImageNet, despite the domain gap.

# %%
# ── Mount Drive & load utils ────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

import sys, shutil, os
UTILS_SRC = "/content/drive/My Drive/thesis/utils"
if os.path.exists(UTILS_SRC):
    shutil.copytree(UTILS_SRC, "/content/utils", dirs_exist_ok=True)
    sys.path.insert(0, "/content")
    print("✅ utils loaded from Drive")
else:
    sys.path.insert(0, "/content")
    print("⚠️  Place the utils/ folder at: My Drive/thesis/utils/")
# Out:
# Mounted at /content/drive
# ✅ utils loaded from Drive

# %%
# ── Standard imports ────────────────────────────────────────────────
import os, time, random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

from utils.dataset import prepare_dataset, get_loaders, get_test_loader
from utils.models  import (
    VGG_Scratch, VGG_Pretrained,
    ResNet_Scratch, ResNet18_Pretrained,
    MobileNetV2_Scratch, MobileNetV3_Pretrained,
    count_params, model_size_mb, MODEL_REGISTRY,
)
from utils.train import (
    setup_device, set_seed, evaluate,
    train_model, train_model_three_phase,
    train_multi_seed, train_kd, plot_history,
)

device = setup_device(seed=41)
# Out:
# Device: cuda

# %%
# ── Dataset setup ───────────────────────────────────────────────────
prepare_dataset()
# Out:
# 1/4 Download
# ⬇️  Downloading VWW archive...
# ✅ Download complete: /content/vww_work/vw_coco2014_96.tar.gz
# 2/4 Extract
# 📦 Extracting VWW archive...
# ✅ Extraction complete: /content/vww_work/extracted
# 3/4 Find root
#    Root: /content/vww_work/extracted/vw_coco2014_96
# 4/4 Manifests
# ✅ Manifests already exist: /content/drive/My Drive/vww_fixed_split_manifests
# PosixPath('/content/vww_work/extracted/vw_coco2014_96')

# %% [markdown]
# ## Standardized hyperparameters
#
# All models use identical settings to ensure fair comparison:
#
# | Parameter | Scratch models | Pretrained models |
# |-----------|---------------|-------------------|
# | Batch size | 64 | 64 |
# | Optimizer | Adam | Adam |
# | Weight decay | 1e-4 | 1e-4 |
# | Label smoothing | 0.1 | 0.1 |
# | Augmentation | standard | standard |
# | Scheduler | CosineAnnealingLR | CosineAnnealingLR |
# | Patience | 10 | 10 |
# | Seeds | [41, 52, 63] | [41, 52, 63] |
# | Max epochs | 50 | 30 |
# | LR | 1e-3 | 3e-4 → 1e-4 → 3e-5 (3-phase) |
#
# Pretrained models use fewer max epochs because transfer learning converges faster.
# The three-phase progressive unfreeze is only applicable to pretrained models.

# %%
SAVE_DIR = "/content/drive/My Drive/Colab Notebooks"

# %%
train_loader, val_loader = get_loaders(batch_size=64, augmentation="standard")
# Out:
# Train: 7000 | Val: 1500 | Batch: 64

# %%
results, best = train_multi_seed(
    model_fn     = VGG_Scratch,
    train_loader = train_loader,
    val_loader   = val_loader,
    device       = device,
    seeds        = [41, 52, 63],
    save_dir     = SAVE_DIR,
    name_prefix  = "vgg_scratch",
    pretrained   = False,
    # Standard scratch hyperparameters
    epochs          = 50,
    lr              = 1e-3,
    weight_decay    = 1e-4,
    label_smoothing = 0.1,
    patience        = 10,
)
# Out:
# ============================================================
# Seed 41
# ============================================================
# Epoch   1/50 | LR 0.000999 | Train 59.77% | Val 64.80% ✅
# Epoch   2/50 | LR 0.000996 | Train 64.31% | Val 60.00%
# Epoch   3/50 | LR 0.000991 | Train 66.63% | Val 64.93% ✅
# Epoch   4/50 | LR 0.000984 | Train 68.36% | Val 67.47% ✅
# Epoch   5/50 | LR 0.000976 | Train 68.09% | Val 70.53% ✅
# Epoch   6/50 | LR 0.000965 | Train 70.19% | Val 69.87%
# Epoch   7/50 | LR 0.000952 | Train 70.33% | Val 68.13%
# Epoch   8/50 | LR 0.000938 | Train 71.33% | Val 73.27% ✅
# Epoch   9/50 | LR 0.000922 | Train 71.57% | Val 72.47%
# Epoch  10/50 | LR 0.000905 | Train 71.97% | Val 70.00%
# Epoch  11/50 | LR 0.000885 | Train 73.24% | Val 70.60%
# Epoch  12/50 | LR 0.000864 | Train 73.66% | Val 73.20%
# Epoch  13/50 | LR 0.000842 | Train 72.99% | Val 75.20% ✅
# Epoch  14/50 | LR 0.000819 | Train 74.19% | Val 75.87% ✅
# Epoch  15/50 | LR 0.000794 | Train 75.46% | Val 76.80% ✅
# Epoch  16/50 | LR 0.000768 | Train 75.29% | Val 74.00%
# Epoch  17/50 | LR 0.000741 | Train 75.74% | Val 73.73%
# Epoch  18/50 | LR 0.000713 | Train 76.41% | Val 76.87% ✅
# Epoch  19/50 | LR 0.000684 | Train 76.20% | Val 74.87%
# Epoch  20/50 | LR 0.000655 | Train 76.01% | Val 75.07%
# Epoch  21/50 | LR 0.000624 | Train 77.16% | Val 74.60%
# Epoch  22/50 | LR 0.000594 | Train 76.84% | Val 75.93%
# Epoch  23/50 | LR 0.000563 | Train 77.84% | Val 77.60% ✅
# Epoch  24/50 | LR 0.000531 | Train 78.27% | Val 77.67% ✅
# Epoch  25/50 | LR 0.000500 | Train 77.64% | Val 78.00% ✅
# Epoch  26/50 | LR 0.000469 | Train 78.17% | Val 78.53% ✅
# Epoch  27/50 | LR 0.000437 | Train 79.04% | Val 77.80%
# Epoch  28/50 | LR 0.000406 | Train 79.71% | Val 78.33%
# Epoch  29/50 | LR 0.000376 | Train 79.73% | Val 78.07%
# Epoch  30/50 | LR 0.000345 | Train 79.76% | Val 77.40%
# Epoch  31/50 | LR 0.000316 | Train 80.77% | Val 79.87% ✅
# Epoch  32/50 | LR 0.000287 | Train 80.57% | Val 78.07%
# Epoch  33/50 | LR 0.000259 | Train 80.70% | Val 79.07%
# Epoch  34/50 | LR 0.000232 | Train 80.47% | Val 78.87%
# Epoch  35/50 | LR 0.000206 | Train 81.43% | Val 78.47%
# Epoch  36/50 | LR 0.000181 | Train 82.07% | Val 78.80%
# Epoch  37/50 | LR 0.000158 | Train 82.50% | Val 80.00% ✅
# Epoch  38/50 | LR 0.000136 | Train 82.51% | Val 79.33%
# Epoch  39/50 | LR 0.000115 | Train 82.87% | Val 79.87%
# Epoch  40/50 | LR 0.000095 | Train 83.53% | Val 79.33%
# Epoch  41/50 | LR 0.000078 | Train 83.43% | Val 79.53%
# Epoch  42/50 | LR 0.000062 | Train 84.11% | Val 79.73%
# Epoch  43/50 | LR 0.000048 | Train 83.90% | Val 80.27% ✅
# Epoch  44/50 | LR 0.000035 | Train 84.54% | Val 80.20%
# Epoch  45/50 | LR 0.000024 | Train 84.70% | Val 80.07%
# Epoch  46/50 | LR 0.000016 | Train 85.17% | Val 79.60%
# Epoch  47/50 | LR 0.000009 | Train 85.33% | Val 79.93%
# Epoch  48/50 | LR 0.000004 | Train 85.37% | Val 79.93%
# Epoch  49/50 | LR 0.000001 | Train 85.57% | Val 79.80%
# Epoch  50/50 | LR 0.000000 | Train 85.31% | Val 80.07%
#
# ✅ Best val acc: 80.27% @ epoch 43  (12.0 min)
#    Saved: /content/drive/My Drive/Colab Notebooks/vgg_scratch_seed_41.pth
#
# ============================================================
# Seed 52
# ============================================================
# Epoch   1/50 | LR 0.000999 | Train 61.19% | Val 63.00% ✅
# Epoch   2/50 | LR 0.000996 | Train 65.41% | Val 66.13% ✅
# Epoch   3/50 | LR 0.000991 | Train 67.16% | Val 67.33% ✅
# Epoch   4/50 | LR 0.000984 | Train 67.70% | Val 65.27%
# Epoch   5/50 | LR 0.000976 | Train 68.70% | Val 67.67% ✅
# Epoch   6/50 | LR 0.000965 | Train 69.00% | Val 70.00% ✅
# Epoch   7/50 | LR 0.000952 | Train 71.01% | Val 72.47% ✅
# Epoch   8/50 | LR 0.000938 | Train 70.66% | Val 71.13%
# Epoch   9/50 | LR 0.000922 | Train 71.99% | Val 73.93% ✅
# Epoch  10/50 | LR 0.000905 | Train 72.09% | Val 73.33%
# Epoch  11/50 | LR 0.000885 | Train 72.80% | Val 73.07%
# Epoch  12/50 | LR 0.000864 | Train 72.20% | Val 73.33%
# Epoch  13/50 | LR 0.000842 | Train 72.94% | Val 71.47%
# Epoch  14/50 | LR 0.000819 | Train 73.79% | Val 74.33% ✅
# Epoch  15/50 | LR 0.000794 | Train 74.79% | Val 68.80%
# Epoch  16/50 | LR 0.000768 | Train 74.61% | Val 73.80%
# Epoch  17/50 | LR 0.000741 | Train 75.37% | Val 74.60% ✅
# Epoch  18/50 | LR 0.000713 | Train 76.34% | Val 70.60%
# Epoch  19/50 | LR 0.000684 | Train 75.64% | Val 75.87% ✅
# Epoch  20/50 | LR 0.000655 | Train 76.33% | Val 75.27%
# Epoch  21/50 | LR 0.000624 | Train 77.74% | Val 73.67%
# Epoch  22/50 | LR 0.000594 | Train 76.70% | Val 76.07% ✅
# Epoch  23/50 | LR 0.000563 | Train 77.56% | Val 76.00%
# Epoch  24/50 | LR 0.000531 | Train 77.86% | Val 75.13%
# Epoch  25/50 | LR 0.000500 | Train 78.39% | Val 76.20% ✅
# Epoch  26/50 | LR 0.000469 | Train 78.60% | Val 77.27% ✅
# Epoch  27/50 | LR 0.000437 | Train 79.13% | Val 75.67%
# Epoch  28/50 | LR 0.000406 | Train 79.47% | Val 75.40%
# Epoch  29/50 | LR 0.000376 | Train 80.27% | Val 77.07%
# Epoch  30/50 | LR 0.000345 | Train 80.36% | Val 75.07%
# Epoch  31/50 | LR 0.000316 | Train 80.36% | Val 76.60%
# Epoch  32/50 | LR 0.000287 | Train 81.39% | Val 77.27%
# Epoch  33/50 | LR 0.000259 | Train 81.06% | Val 78.33% ✅
# Epoch  34/50 | LR 0.000232 | Train 82.17% | Val 78.20%
# Epoch  35/50 | LR 0.000206 | Train 82.16% | Val 78.13%
# Epoch  36/50 | LR 0.000181 | Train 82.36% | Val 77.60%
# Epoch  37/50 | LR 0.000158 | Train 82.70% | Val 78.27%
# Epoch  38/50 | LR 0.000136 | Train 83.74% | Val 78.27%
# Epoch  39/50 | LR 0.000115 | Train 83.06% | Val 79.20% ✅
# Epoch  40/50 | LR 0.000095 | Train 83.49% | Val 78.07%
# Epoch  41/50 | LR 0.000078 | Train 84.49% | Val 78.33%
# Epoch  42/50 | LR 0.000062 | Train 83.91% | Val 78.73%
# Epoch  43/50 | LR 0.000048 | Train 84.61% | Val 78.60%
# Epoch  44/50 | LR 0.000035 | Train 84.89% | Val 79.67% ✅
# Epoch  45/50 | LR 0.000024 | Train 84.59% | Val 79.27%
# Epoch  46/50 | LR 0.000016 | Train 85.39% | Val 78.87%
# Epoch  47/50 | LR 0.000009 | Train 85.01% | Val 79.27%
# Epoch  48/50 | LR 0.000004 | Train 85.53% | Val 79.60%
# Epoch  49/50 | LR 0.000001 | Train 85.61% | Val 79.60%
# Epoch  50/50 | LR 0.000000 | Train 85.84% | Val 79.47%
#
# ✅ Best val acc: 79.67% @ epoch 44  (11.8 min)
#    Saved: /content/drive/My Drive/Colab Notebooks/vgg_scratch_seed_52.pth
#
# ============================================================
# Seed 63
# ============================================================
# Epoch   1/50 | LR 0.000999 | Train 60.36% | Val 64.87% ✅
# Epoch   2/50 | LR 0.000996 | Train 64.60% | Val 68.07% ✅
# Epoch   3/50 | LR 0.000991 | Train 67.23% | Val 68.80% ✅
# Epoch   4/50 | LR 0.000984 | Train 66.89% | Val 66.40%
# Epoch   5/50 | LR 0.000976 | Train 68.17% | Val 68.60%
# Epoch   6/50 | LR 0.000965 | Train 69.70% | Val 68.40%
# Epoch   7/50 | LR 0.000952 | Train 69.66% | Val 71.07% ✅
# Epoch   8/50 | LR 0.000938 | Train 71.44% | Val 71.07%
# Epoch   9/50 | LR 0.000922 | Train 71.30% | Val 70.93%
# Epoch  10/50 | LR 0.000905 | Train 71.20% | Val 72.47% ✅
# Epoch  11/50 | LR 0.000885 | Train 72.51% | Val 70.07%
# Epoch  12/50 | LR 0.000864 | Train 72.64% | Val 72.53% ✅
# Epoch  13/50 | LR 0.000842 | Train 73.26% | Val 74.53% ✅
# Epoch  14/50 | LR 0.000819 | Train 73.84% | Val 73.33%
# Epoch  15/50 | LR 0.000794 | Train 74.23% | Val 71.33%
# Epoch  16/50 | LR 0.000768 | Train 74.99% | Val 73.93%
# Epoch  17/50 | LR 0.000741 | Train 74.61% | Val 75.33% ✅
# Epoch  18/50 | LR 0.000713 | Train 75.34% | Val 73.40%
# Epoch  19/50 | LR 0.000684 | Train 75.71% | Val 76.53% ✅
# Epoch  20/50 | LR 0.000655 | Train 75.57% | Val 75.67%
# Epoch  21/50 | LR 0.000624 | Train 76.69% | Val 76.00%
# Epoch  22/50 | LR 0.000594 | Train 77.29% | Val 75.93%
# Epoch  23/50 | LR 0.000563 | Train 76.39% | Val 75.20%
# Epoch  24/50 | LR 0.000531 | Train 77.43% | Val 75.67%
# Epoch  25/50 | LR 0.000500 | Train 77.14% | Val 75.27%
# Epoch  26/50 | LR 0.000469 | Train 77.80% | Val 75.00%
# Epoch  27/50 | LR 0.000437 | Train 77.91% | Val 76.67% ✅
# Epoch  28/50 | LR 0.000406 | Train 78.99% | Val 77.20% ✅
# Epoch  29/50 | LR 0.000376 | Train 78.46% | Val 77.20%
# Epoch  30/50 | LR 0.000345 | Train 79.31% | Val 77.27% ✅
# Epoch  31/50 | LR 0.000316 | Train 79.64% | Val 73.67%
# Epoch  32/50 | LR 0.000287 | Train 79.89% | Val 77.93% ✅
# Epoch  33/50 | LR 0.000259 | Train 80.46% | Val 78.27% ✅
# Epoch  34/50 | LR 0.000232 | Train 80.80% | Val 78.20%
# Epoch  35/50 | LR 0.000206 | Train 80.54% | Val 78.13%
# Epoch  36/50 | LR 0.000181 | Train 81.43% | Val 77.47%
# Epoch  37/50 | LR 0.000158 | Train 81.57% | Val 79.60% ✅
# Epoch  38/50 | LR 0.000136 | Train 81.83% | Val 78.00%
# Epoch  39/50 | LR 0.000115 | Train 82.19% | Val 79.20%
# Epoch  40/50 | LR 0.000095 | Train 83.24% | Val 77.73%
# Epoch  41/50 | LR 0.000078 | Train 82.59% | Val 78.93%
# Epoch  42/50 | LR 0.000062 | Train 82.91% | Val 78.40%
# Epoch  43/50 | LR 0.000048 | Train 83.16% | Val 78.73%
# Epoch  44/50 | LR 0.000035 | Train 83.87% | Val 78.20%
# Epoch  45/50 | LR 0.000024 | Train 83.19% | Val 78.00%
# Epoch  46/50 | LR 0.000016 | Train 83.89% | Val 78.80%
# Epoch  47/50 | LR 0.000009 | Train 84.06% | Val 78.47%
# 🛑 Early stopping at epoch 47  (best: 79.60% @ ep 37)
#
# ✅ Best val acc: 79.60% @ epoch 37  (10.8 min)
#    Saved: /content/drive/My Drive/Colab Notebooks/vgg_scratch_seed_63.pth
#
# ============================================================
# Multi-seed summary  [vgg_scratch]
# ============================================================
#   Seed 41: 80.27% @ ep 43
#   Seed 52: 79.67% @ ep 44
#   Seed 63: 79.60% @ ep 37
#   Mean ± Std: 79.84% ± 0.30%
#   Best: seed 41  80.27%
#   Checkpoint: /content/drive/My Drive/Colab Notebooks/vgg_scratch_seed_41.pth

# %%
plot_history(best, title=f"VGG Scratch (seed {best['seed']})")

accs = [r["best_acc"] for r in results]
print(f"\nVGG Scratch  |  Mean: {np.mean(accs)*100:.2f}% ± {np.std(accs)*100:.2f}%  |  "
      f"Best: {best['best_acc']*100:.2f}% (seed {best['seed']})")
print(f"Best checkpoint: {best['save_path']}")
# Out:
# Best: 80.27% @ epoch 43  (12.0 min)
#
# VGG Scratch  |  Mean: 79.84% ± 0.30%  |  Best: 80.27% (seed 41)
# Best checkpoint: /content/drive/My Drive/Colab Notebooks/vgg_scratch_seed_41.pth
